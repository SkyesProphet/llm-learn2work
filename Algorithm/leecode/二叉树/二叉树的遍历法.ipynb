# %% [markdown]
# ### 102.二叉树的层序遍历
# 给你二叉树的根节点 root ，返回其节点值的 层序遍历 。 （即逐层地，从左到右访问所有节点）。
#
# 示例 1：
# 输入：root = [3,9,20,null,null,15,7]
# 输出：[[3],[9,20],[15,7]]
#
# 示例 2：
# 输入：root = [1]
# 输出：[[1]]
#
# 示例 3：
# 输入：root = []
# 输出：[]

# %% [markdown]
# #### 1. BFS（广度优先搜索）
# BFS 通常借助 队列 的先入先出特性来实现。
#
# 每层打印到一行： 将本层全部节点打印到一行，并将下一层全部节点加入队列，以此类推，即可分为多行打印。

# %%
from typing import List, Optional
import collections
class TreeNode:
    def __init__(self, val=0, left=None, right=None):
        self.val = val
        self.left = left
        self.right = right
class Solution:
    def levelOrder(self, root: Optional[TreeNode]) -> List[List[int]]:
        # 使用队列 BFS
        if not root: return []
        res = []
        queue = collections.deque([root])
        # 当队列不为空时，继续遍历
        while queue: 
            level = []         # 遍历当前层的所有节点
            for  i in range(len(queue)):
                node = queue.popleft() # 队列左取出一个节点
                level.append(node.val) # 将节点值添加到当前层的结果中
                if node.left:
                    queue.append(node.left) # 默认从右侧添加节点

                if node.right:
                    queue.append(node.right)
            res.append(level)
        return res


# root = [3,9,20,None,None,15,7]
# 还需自己构建二叉树
root = TreeNode(3)
root.left = TreeNode(9)
root.right = TreeNode(20)
root.right.left = TreeNode(15)
root.right.right = TreeNode(7)   

s = Solution() # 初始化解决对象
print(s.levelOrder(root)) # 输出结果
# Out:
# [[3], [9, 20], [15, 7]]
